# %% [markdown]
# # Passo a passo do desafio
# ### 1. Entrar no sistema da empresa (link do Drive)
# ##### abrir o Chrome
# ##### digitar o link do sistema
# ##### apertei enter e esperei
# ### 2. Navegar no sistema para encontrar a base de dados
# ### 3. Exportar a base de dados (baixar o arquivo)
# ### 4. Calcular os indicadores (Faturamento e quantidade de produtos vendidos)
# ### 5. Enviar as informações por e-mail.

# %%
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/thaisribeirocarvalho/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Downloading pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 58.5 MB/s  0:00:00
# Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 57.6 MB/s  0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# Successfully installed numpy-2.0.2 pandas-2.3.3 pytz-2025.2 tzdata-2025.3

# %%
#!pip install pyautogui
#!pip install openpyxl
# pyautogui = automacoes 
# pandas = dados
# openpyxls = trabalhar com bases de dados em Excel (.xlsx)

# %%
import pyautogui
import time

# pyautogui.PAUSE -> pausa a cada linha de comando 
#time.sleep -> após o ultimo comando.

# %%
# !pip install python-dotenv
# para armazenar dados sensiveis
import os
from dotenv import load_dotenv
load_dotenv()
link = os.getenv('LINK')

# %%
# abrir o site usando o Chrome
pyautogui.hotkey('command', 'space')
pyautogui.write('Google Chrome')
pyautogui.press('return')
time.sleep(0.5)
# digitar o link do sistema
pyautogui.write(link)
pyautogui.press('return')
